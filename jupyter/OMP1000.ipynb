# %%
import json
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
target_path100 = r"F:\PW\sem8\PORR\mobile_robot_computing\results\OMP1000.json"

# %%
with open(target_path100) as json_file:
    result = json.load(json_file)

# %%
durations = [float(d["duration"]) for d in result]

# %%
np.shape(result)
# Out:
# (40,)

# %%
data = pd.DataFrame(result)

# %%
data
# Out:
#    cost_best_path   duration      graph                           name  \
# 0         1.43702  162945460  graph1000  graph1000_iters10000_threads1
# 1         1.45009  149364372  graph1000  graph1000_iters10000_threads1
# 2         1.43044  144476361  graph1000  graph1000_iters10000_threads1
# 3         1.42732  136003183  graph1000  graph1000_iters10000_threads1
# 4         1.43891  157875635  graph1000  graph1000_iters10000_threads1
# 5         1.43055   75652965  graph1000  graph1000_iters10000_threads2
# 6         1.44804   79731244  graph1000  graph1000_iters10000_threads2
# 7         1.45842   69273852  graph1000  graph1000_iters10000_threads2
# 8         1.43107   91074745  graph1000  graph1000_iters10000_threads2
# 9         1.44387   75811186  graph1000  graph1000_iters10000_threads2
# 10        1.44871   55732249  graph1000  graph1000_iters10000_threads3
# 11        1.44515   60471356  graph1000  graph1000_iters10000_threads3
# 12         1.4401   54228009  graph1000  graph1000_iters10000_threads3
# 13        1.45387   62590675  graph1000  graph1000_iters10000_threads3
# 14        1.43098   54938179  graph1000  graph1000_iters10000_threads3
# 15        1.46664   47985582  graph1000  graph1000_iters10000_threads4
# 16        1.44319   47523820  graph1000  graph1000_iters10000_threads4
# 17        1.45685   47565792  graph1000  graph1000_iters10000_threads4
# 18        1.45166   53074672  graph1000  graph1000_iters10000_threads4
# 19         1.4673   45471897  graph1000  graph1000_iters10000_threads4
# 20        1.43735   49419557  graph1000  graph1000_iters10000_threads5
# 21        1.43045   52363544  graph1000  graph1000_iters10000_threads5
# 22        1.43881   54776010  graph1000  graph1000_iters10000_threads5
# 23        1.44952   59105314  graph1000  graph1000_iters10000_threads5
# 24        1.45258   53260502  graph1000  graph1000_iters10000_threads5
# 25        1.44023   46043298  graph1000  graph1000_iters10000_threads6
# 26        1.46029   45059147  graph1000  graph1000_iters10000_threads6
# 27        1.43872   48383300  graph1000  graph1000_iters10000_threads6
# 28        1.45082   41233866  graph1000  graph1000_iters10000_threads6
# 29        1.44814   52996274  graph1000  graph1000_iters10000_threads6
# 30        1.46894   43484992  graph1000  graph1000_iters10000_threads7
# 31        1.44601   44774631  graph1000  graph1000_iters10000_threads7
# 32        1.42147   36724257  graph1000  graph1000_iters10000_threads7
# 33        1.45175   46006706  graph1000  graph1000_iters10000_threads7
# 34        1.45741   38251462  graph1000  graph1000_iters10000_threads7
# 35        1.45192   53273325  graph1000  graph1000_iters10000_threads8
# 36        1.42552   46717763  graph1000  graph1000_iters10000_threads8
# 37        1.44751   48287305  graph1000  graph1000_iters10000_threads8
# 38        1.46348   44260812  graph1000  graph1000_iters10000_threads8
# 39        1.45752   39524412  graph1000  graph1000_iters10000_threads8
#
#     nr_of_iteration  nr_of_threads
# 0             10000              1
# 1             10000              1
# 2             10000              1
# 3             10000              1
# 4             10000              1
# 5             10000              2
# 6             10000              2
# 7             10000              2
# 8             10000              2
# 9             10000              2
# 10            10000              3
# 11            10000              3
# 12            10000              3
# 13            10000              3
# 14            10000              3
# 15            10000              4
# 16            10000              4
# 17            10000              4
# 18            10000              4
# 19            10000              4
# 20            10000              5
# 21            10000              5
# 22            10000              5
# 23            10000              5
# 24            10000              5
# 25            10000              6
# 26            10000              6
# 27            10000              6
# 28            10000              6
# 29            10000              6
# 30            10000              7
# 31            10000              7
# 32            10000              7
# 33            10000              7
# 34            10000              7
# 35            10000              8
# 36            10000              8
# 37            10000              8
# 38            10000              8
# 39            10000              8

# %%
data.duration = data.duration.astype(dtype='float64')
data.cost_best_path = data.cost_best_path.astype(dtype='float64')

# %%
data.plot.scatter(x='nr_of_threads', y='duration', title='Czas trwania programu dla grafu o 100 węzłach')
plt.ylabel('Duration [s]')
plt.xlabel('Number of threads')
# Out:
# Text(0.5,0,'Number of threads')

# %%
data2 = data.loc[data.nr_of_threads != 1]

# %%
data2.plot.scatter(x='nr_of_threads', y='duration', title='Czas trwania programu (Obl. wielowątkowe) graf 100 węzłów')
plt.ylabel('Duration [s]')
plt.xlabel('Number of threads')
# Out:
# Text(0.5,0,'Number of threads')

# %%
data.duration = data.duration *0.000001

# %%
data2
# Out:
#     cost_best_path    duration      graph                           name  \
# 5          1.43055  75652965.0  graph1000  graph1000_iters10000_threads2
# 6          1.44804  79731244.0  graph1000  graph1000_iters10000_threads2
# 7          1.45842  69273852.0  graph1000  graph1000_iters10000_threads2
# 8          1.43107  91074745.0  graph1000  graph1000_iters10000_threads2
# 9          1.44387  75811186.0  graph1000  graph1000_iters10000_threads2
# 10         1.44871  55732249.0  graph1000  graph1000_iters10000_threads3
# 11         1.44515  60471356.0  graph1000  graph1000_iters10000_threads3
# 12         1.44010  54228009.0  graph1000  graph1000_iters10000_threads3
# 13         1.45387  62590675.0  graph1000  graph1000_iters10000_threads3
# 14         1.43098  54938179.0  graph1000  graph1000_iters10000_threads3
# 15         1.46664  47985582.0  graph1000  graph1000_iters10000_threads4
# 16         1.44319  47523820.0  graph1000  graph1000_iters10000_threads4
# 17         1.45685  47565792.0  graph1000  graph1000_iters10000_threads4
# 18         1.45166  53074672.0  graph1000  graph1000_iters10000_threads4
# 19         1.46730  45471897.0  graph1000  graph1000_iters10000_threads4
# 20         1.43735  49419557.0  graph1000  graph1000_iters10000_threads5
# 21         1.43045  52363544.0  graph1000  graph1000_iters10000_threads5
# 22         1.43881  54776010.0  graph1000  graph1000_iters10000_threads5
# 23         1.44952  59105314.0  graph1000  graph1000_iters10000_threads5
# 24         1.45258  53260502.0  graph1000  graph1000_iters10000_threads5
# 25         1.44023  46043298.0  graph1000  graph1000_iters10000_threads6
# 26         1.46029  45059147.0  graph1000  graph1000_iters10000_threads6
# 27         1.43872  48383300.0  graph1000  graph1000_iters10000_threads6
# 28         1.45082  41233866.0  graph1000  graph1000_iters10000_threads6
# 29         1.44814  52996274.0  graph1000  graph1000_iters10000_threads6
# 30         1.46894  43484992.0  graph1000  graph1000_iters10000_threads7
# 31         1.44601  44774631.0  graph1000  graph1000_iters10000_threads7
# 32         1.42147  36724257.0  graph1000  graph1000_iters10000_threads7
# 33         1.45175  46006706.0  graph1000  graph1000_iters10000_threads7
# 34         1.45741  38251462.0  graph1000  graph1000_iters10000_threads7
# 35         1.45192  53273325.0  graph1000  graph1000_iters10000_threads8
# 36         1.42552  46717763.0  graph1000  graph1000_iters10000_threads8
# 37         1.44751  48287305.0  graph1000  graph1000_iters10000_threads8
# 38         1.46348  44260812.0  graph1000  graph1000_iters10000_threads8
# 39         1.45752  39524412.0  graph1000  graph1000_iters10000_threads8
#
#     nr_of_iteration  nr_of_threads
# 5             10000              2
# 6             10000              2
# 7             10000              2
# 8             10000              2
# 9             10000              2
# 10            10000              3
# 11            10000              3
# 12            10000              3
# 13            10000              3
# 14            10000              3
# 15            10000              4
# 16            10000              4
# 17            10000              4
# 18            10000              4
# 19            10000              4
# 20            10000              5
# 21            10000              5
# 22            10000              5
# 23            10000              5
# 24            10000              5
# 25            10000              6
# 26            10000              6
# 27            10000              6
# 28            10000              6
# 29            10000              6
# 30            10000              7
# 31            10000              7
# 32            10000              7
# 33            10000              7
# 34            10000              7
# 35            10000              8
# 36            10000              8
# 37            10000              8
# 38            10000              8
# 39            10000              8

# %% [markdown]
# Średnia wartość czasu obliczeń

# %%
mean_duration = []
for i in range(1, 9):
    mean_duration.append(data.loc[data.nr_of_threads == i].duration.mean())

# %%
plt.plot(range(1, 9), mean_duration, 'bo')
plt.title('Średnia wartość czasu trwania programu dla różnej ilości wątków 100 węzłów')
plt.ylabel('Mean duration [s]')
plt.xlabel('Number of threads')
# Out:
# Text(0.5,0,'Number of threads')

# %% [markdown]
# Współczynnik przyśpieszenia
# S(n, p) = T(n, 1)/T(n, p)

# %%
speed_up = [mean_duration[0]/i for i in mean_duration]

# %%
speed_up
# Out:
# [1.0,
#  1.917192004825859,
#  2.606833556750575,
#  3.1067773104527845,
#  2.7913552654789795,
#  3.211869877821955,
#  3.58754379521271,
#  3.234738045990209]

# %% [markdown]
# Wydajnosc S(n, p) = S(n, p)/p *100%

# %%
wydajnosc = [i/(idx+1)*100 for idx, i in enumerate(speed_up)]

# %%
wydajnosc
# Out:
# [100.0,
#  95.85960024129295,
#  86.89445189168583,
#  77.66943276131961,
#  55.82710530957959,
#  53.53116463036592,
#  51.25062564589585,
#  40.434225574877615]

# %%
plt.plot(range(1, 9), speed_up,  label = "wsp. przyśpieszenia")
plt.title('Wskaźniki jakości')
plt.xlabel('Number of threads')
plt.legend()

# %%
plt.plot(range(1, 9), wydajnosc,  label = "wydajność")
plt.title('Wskaźniki jakości')
plt.xlabel('Number of threads')
plt.legend()
