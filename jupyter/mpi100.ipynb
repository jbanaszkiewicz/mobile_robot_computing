# %%
import json
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
target_path100 = r"F:\PW\sem8\PORR\mobile_robot_computing\results\mpi100.json"

# %%
with open(target_path100) as json_file:
    result = json.load(json_file)

# %%
durations = [float(d["duration"]) for d in result]

# %%
np.shape(result)
# Out:
# (40,)

# %%
data = pd.DataFrame(result)

# %%
data
# Out:
#    cost_best_path duration     graph                         name  \
# 0         1.49389  3553707  graph100  graph100_iters1000_threads1
# 1         1.49389  3643402  graph100  graph100_iters1000_threads1
# 2         1.49389  3545085  graph100  graph100_iters1000_threads1
# 3         1.49389  3568370  graph100  graph100_iters1000_threads1
# 4         1.49389  3797216  graph100  graph100_iters1000_threads1
# 5         1.49389  1874106  graph100  graph100_iters1000_threads2
# 6         1.49389  1844941  graph100  graph100_iters1000_threads2
# 7         1.49389  1849120  graph100  graph100_iters1000_threads2
# 8         1.49389  1854161  graph100  graph100_iters1000_threads2
# 9         1.49389  1894697  graph100  graph100_iters1000_threads2
# 10        1.49389  1269537  graph100  graph100_iters1000_threads3
# 11        1.49389  1273016  graph100  graph100_iters1000_threads3
# 12        1.49389  1278373  graph100  graph100_iters1000_threads3
# 13        1.49389  1265326  graph100  graph100_iters1000_threads3
# 14        1.49389  1255966  graph100  graph100_iters1000_threads3
# 15        1.49367  1130111  graph100  graph100_iters1000_threads4
# 16        1.49367  1444397  graph100  graph100_iters1000_threads4
# 17        1.49367  1070504  graph100  graph100_iters1000_threads4
# 18        1.49367   917818  graph100  graph100_iters1000_threads4
# 19        1.49367   906876  graph100  graph100_iters1000_threads4
# 20        1.47489  1055563  graph100  graph100_iters1000_threads5
# 21        1.47489  1059590  graph100  graph100_iters1000_threads5
# 22        1.47489  1212680  graph100  graph100_iters1000_threads5
# 23        1.47489  1074885  graph100  graph100_iters1000_threads5
# 24        1.47489  1047026  graph100  graph100_iters1000_threads5
# 25        1.47489   946268  graph100  graph100_iters1000_threads6
# 26        1.47489   945815  graph100  graph100_iters1000_threads6
# 27        1.47489   933394  graph100  graph100_iters1000_threads6
# 28        1.47489  1028157  graph100  graph100_iters1000_threads6
# 29        1.47489   948623  graph100  graph100_iters1000_threads6
# 30        1.50341   874025  graph100  graph100_iters1000_threads7
# 31        1.50341   856646  graph100  graph100_iters1000_threads7
# 32        1.50341   862702  graph100  graph100_iters1000_threads7
# 33        1.50341   847954  graph100  graph100_iters1000_threads7
# 34        1.50341   846542  graph100  graph100_iters1000_threads7
# 35        1.50341  1035013  graph100  graph100_iters1000_threads8
# 36        1.50341   870556  graph100  graph100_iters1000_threads8
# 37        1.50341  1062739  graph100  graph100_iters1000_threads8
# 38        1.50341  1008582  graph100  graph100_iters1000_threads8
# 39        1.50341   873342  graph100  graph100_iters1000_threads8
#
#     nr_of_iteration  nr_of_threads
# 0              1000              1
# 1              1000              1
# 2              1000              1
# 3              1000              1
# 4              1000              1
# 5              1000              2
# 6              1000              2
# 7              1000              2
# 8              1000              2
# 9              1000              2
# 10             1000              3
# 11             1000              3
# 12             1000              3
# 13             1000              3
# 14             1000              3
# 15             1000              4
# 16             1000              4
# 17             1000              4
# 18             1000              4
# 19             1000              4
# 20             1000              5
# 21             1000              5
# 22             1000              5
# 23             1000              5
# 24             1000              5
# 25             1000              6
# 26             1000              6
# 27             1000              6
# 28             1000              6
# 29             1000              6
# 30             1000              7
# 31             1000              7
# 32             1000              7
# 33             1000              7
# 34             1000              7
# 35             1000              8
# 36             1000              8
# 37             1000              8
# 38             1000              8
# 39             1000              8

# %%
data.duration = data.duration.astype(dtype='float64')
data.cost_best_path = data.cost_best_path.astype(dtype='float64')

# %%
data.plot.scatter(x='nr_of_threads', y='duration', title='Czas trwania programu dla grafu o 100 węzłach')
plt.ylabel('Duration [s]')
plt.xlabel('Number of threads')
# Out:
# Text(0.5,0,'Number of threads')

# %%
data2 = data.loc[data.nr_of_threads != 1]

# %%
data2.plot.scatter(x='nr_of_threads', y='duration', title='Czas trwania programu (Obl. wielowątkowe) graf 100 węzłów')
plt.ylabel('Duration [s]')
plt.xlabel('Number of threads')
# Out:
# Text(0.5,0,'Number of threads')

# %%
data.duration = data.duration *0.000001

# %%
data2
# Out:
#     cost_best_path   duration     graph                         name  \
# 5          1.49389  1874106.0  graph100  graph100_iters1000_threads2
# 6          1.49389  1844941.0  graph100  graph100_iters1000_threads2
# 7          1.49389  1849120.0  graph100  graph100_iters1000_threads2
# 8          1.49389  1854161.0  graph100  graph100_iters1000_threads2
# 9          1.49389  1894697.0  graph100  graph100_iters1000_threads2
# 10         1.49389  1269537.0  graph100  graph100_iters1000_threads3
# 11         1.49389  1273016.0  graph100  graph100_iters1000_threads3
# 12         1.49389  1278373.0  graph100  graph100_iters1000_threads3
# 13         1.49389  1265326.0  graph100  graph100_iters1000_threads3
# 14         1.49389  1255966.0  graph100  graph100_iters1000_threads3
# 15         1.49367  1130111.0  graph100  graph100_iters1000_threads4
# 16         1.49367  1444397.0  graph100  graph100_iters1000_threads4
# 17         1.49367  1070504.0  graph100  graph100_iters1000_threads4
# 18         1.49367   917818.0  graph100  graph100_iters1000_threads4
# 19         1.49367   906876.0  graph100  graph100_iters1000_threads4
# 20         1.47489  1055563.0  graph100  graph100_iters1000_threads5
# 21         1.47489  1059590.0  graph100  graph100_iters1000_threads5
# 22         1.47489  1212680.0  graph100  graph100_iters1000_threads5
# 23         1.47489  1074885.0  graph100  graph100_iters1000_threads5
# 24         1.47489  1047026.0  graph100  graph100_iters1000_threads5
# 25         1.47489   946268.0  graph100  graph100_iters1000_threads6
# 26         1.47489   945815.0  graph100  graph100_iters1000_threads6
# 27         1.47489   933394.0  graph100  graph100_iters1000_threads6
# 28         1.47489  1028157.0  graph100  graph100_iters1000_threads6
# 29         1.47489   948623.0  graph100  graph100_iters1000_threads6
# 30         1.50341   874025.0  graph100  graph100_iters1000_threads7
# 31         1.50341   856646.0  graph100  graph100_iters1000_threads7
# 32         1.50341   862702.0  graph100  graph100_iters1000_threads7
# 33         1.50341   847954.0  graph100  graph100_iters1000_threads7
# 34         1.50341   846542.0  graph100  graph100_iters1000_threads7
# 35         1.50341  1035013.0  graph100  graph100_iters1000_threads8
# 36         1.50341   870556.0  graph100  graph100_iters1000_threads8
# 37         1.50341  1062739.0  graph100  graph100_iters1000_threads8
# 38         1.50341  1008582.0  graph100  graph100_iters1000_threads8
# 39         1.50341   873342.0  graph100  graph100_iters1000_threads8
#
#     nr_of_iteration  nr_of_threads
# 5              1000              2
# 6              1000              2
# 7              1000              2
# 8              1000              2
# 9              1000              2
# 10             1000              3
# 11             1000              3
# 12             1000              3
# 13             1000              3
# 14             1000              3
# 15             1000              4
# 16             1000              4
# 17             1000              4
# 18             1000              4
# 19             1000              4
# 20             1000              5
# 21             1000              5
# 22             1000              5
# 23             1000              5
# 24             1000              5
# 25             1000              6
# 26             1000              6
# 27             1000              6
# 28             1000              6
# 29             1000              6
# 30             1000              7
# 31             1000              7
# 32             1000              7
# 33             1000              7
# 34             1000              7
# 35             1000              8
# 36             1000              8
# 37             1000              8
# 38             1000              8
# 39             1000              8

# %% [markdown]
# Średnia wartość czasu obliczeń

# %%
mean_duration = []
for i in range(1, 9):
    mean_duration.append(data.loc[data.nr_of_threads == i].duration.mean())

# %%
plt.plot(range(1, 9), mean_duration, 'bo')
plt.title('Średnia wartość czasu trwania programu dla różnej ilości wątków 100 węzłów')
plt.ylabel('Mean duration [s]')
plt.xlabel('Number of threads')
# Out:
# Text(0.5,0,'Number of threads')

# %% [markdown]
# Współczynnik przyśpieszenia
# S(n, p) = T(n, 1)/T(n, p)

# %%
speed_up = [mean_duration[0]/i for i in mean_duration]

# %%
speed_up
# Out:
# [1.0,
#  1.943515231525084,
#  2.8551178783195406,
#  3.3105581908789983,
#  3.322684515089149,
#  3.770681160962439,
#  4.223025470227752,
#  3.733384299967507]

# %% [markdown]
# Wydajnosc S(n, p) = S(n, p)/p *100%

# %%
wydajnosc = [i/(idx+1)*100 for idx, i in enumerate(speed_up)]

# %%
wydajnosc
# Out:
# [100.0,
#  97.1757615762542,
#  95.17059594398468,
#  82.76395477197495,
#  66.45369030178297,
#  62.844686016040654,
#  60.32893528896788,
#  46.667303749593835]

# %%
plt.plot(range(1, 9), speed_up,  label = "wsp. przyśpieszenia")
plt.title('Wskaźniki jakości')
plt.xlabel('Number of threads')
plt.legend()

# %%
plt.plot(range(1, 9), wydajnosc,  label = "wydajność")
plt.title('Wskaźniki jakości')
plt.xlabel('Number of threads')
plt.legend()
